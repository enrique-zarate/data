# %%
import camelot
import plotly.express as px

# %%
# extract all the tables in the PDF file
tables = camelot.read_pdf("pdfs/pdf1.pdf", pages='1-end')   #address of file location
 
# print the first table as Pandas DataFrame
# tables_df = tables[6].df.head()
print('Total tables extracted:', tables.n)
# Out:
# Total tables extracted: 12

# %% [markdown]
# # Cleaning

# %%
# Funcion de filtrado de lineas que no tienen todos los datos
# Sirve para sacar las lineas totalizadoras
def get_empty_rows(dataset):
    # Nested 'for' loop and unique value list of 'set'
    return list(set([i for i, s in dataset.iterrows() for v in s.values if str(v) == 'nan']))

# %% [markdown]
# # Primer PDF

# %%
import pandas as pd

# %%
year = "2021"

# Declarar cabecera
header = ['NRO'
          ,'RUC'
          ,'NOMBRE O RAZON SOCIAL'
          ,'APORTE TOTAL(mm)'
        ]

# create a empty dataframe
df_contenedor = pd.DataFrame(columns=header)

# iterar por cada tabla del PDF
for table in tables:
  df = table.df
  # remove the first row with loc
  df = df.loc[1:]
  df.columns = header
  df.loc[:, 'ANHO'] = int(year)


  # df = df.loc[df['NRO'].notnull()]
  # df = df.dropna(subset=['Nro'])

  # concatenate the dataframe into a container dataframe
  df_contenedor = pd.concat([df_contenedor, df], ignore_index=True)

  list_of_empty_rows = get_empty_rows(df)

  # remove rows of list_of_empty_rows off of df_contenedor
# remove rows with empty string based on NRO column with loc
df_contenedor = df_contenedor.loc[df_contenedor['NRO'] != '']
df_contenedor = df_contenedor.drop(list_of_empty_rows)

df_contenedor['APORTE TOTAL(mm)'] = df_contenedor['APORTE TOTAL(mm)'].str.replace('.', '')
# Out:
# /tmp/ipykernel_21366/2158401008.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ANHO'] = year
# /tmp/ipykernel_21366/2158401008.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ANHO'] = year
# /tmp/ipykernel_21366/2158401008.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ANHO'] = year
# /tmp/ipykernel_21366/2158401008.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ANHO'] = year
# /tmp/ipykernel_21366/2158401008.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ANHO'] = year
# /tmp/ipykernel_21366/2158401008.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ANHO'] = year
# /tmp/ipykernel_21366/2158401008.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ANHO'] = year
# /tmp/ipykernel_21366/2158401008.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ANHO'] = year
# /tmp/ipykernel_21366/2158401008.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ANHO'] = year
# /tmp/ipykernel_21366/2158401008.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ANHO'] = year
# /tmp/ipykernel_21366/2158401008.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ANHO'] = year
# /tmp/ipykernel_21366/2158401008.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ANHO'] = year
# /tmp/ipykernel_21366/2158401008.py:35: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_contenedor['APORTE TOTAL(mm)'] = df_contenedor['APORTE TOTAL(mm)'].str.replace('.', '')

# %%
df_contenedor.tail(5)
# Out:
#      NRO       RUC                              NOMBRE O RAZON SOCIAL  \
# 495  496  80037706  BUREAU VERITAS PARAGUAY SOCIEDAD DE RESPONSABI...
# 496  497  80026564                             CHACO INTERNACIONAL SA
# 497  498  80105006                          WILLFARM SOCIEDAD ANONIMA
# 498  499  80024060                          ATENIL SA (SUC. PARAGUAY)
# 499  500  80082380                GRANOS Y NUTRICIÓN SOCIEDAD ANÓNIMA
#
#     APORTE TOTAL(mm)  ANHO
# 495             3303  2021
# 496             3293  2021
# 497             3289  2021
# 498             3261  2021
# 499             3259  2021

# %%
# crear un DF madre y concatenar el DF df_contenedor
df_madre = pd.DataFrame(columns=header)
df_madre = pd.concat([df_madre, df_contenedor], ignore_index=True)
df_madre.head(5)
# Out:
#   NRO       RUC                           NOMBRE O RAZON SOCIAL  \
# 0   1  80009735  ADMINISTRACION NACIONAL DE ELECTRICIDAD - ANDE
# 1   2  80008790                          TABACALERA DEL ESTE SA
# 2   3  80002201                         BANCO ITAU PARAGUAY S.A
# 3   4  80003400                           PARAGUAY REFRESCOS SA
# 4   5  80086846                                   CERVEPAR S.A.
#
#   APORTE TOTAL(mm)  ANHO
# 0           336481  2021
# 1           198331  2021
# 2           174807  2021
# 3           147677  2021
# 4           146989  2021

# %% [markdown]
# # Segundo PDF
# ! sin columna RUC

# %%
# obtener DF del segundo PDF
tables = camelot.read_pdf("pdfs/pdf2.pdf", pages='1-end')
print('Total tables extracted:', tables.n)
# Out:
# Total tables extracted: 12

# %%
year = "2020"

# Declarar cabecera
header = ['NRO'
          # ,'RUC'
          ,'NOMBRE O RAZON SOCIAL'
          ,'APORTE TOTAL(mm)'
        ]

# create a empty dataframe
df_contenedor = pd.DataFrame(columns=header)

# iterar por cada tabla del PDF
for table in tables:
    df = table.df
    # remove the first row with loc
    df = df.loc[1:]
    df.columns = header
    df.loc[:, 'ANHO'] = int(year)


    # remove rows with empty string based on NRO column with loc
    df = df.loc[df['NRO'] != '']
    # df = df.loc[df['NRO'].notnull()]
    # df = df.dropna(subset=['Nro'])

    # concatenate the dataframe into a container dataframe
    df_contenedor = pd.concat([df_contenedor, df], ignore_index=True)

    list_of_empty_rows = get_empty_rows(df)

    # remove rows of list_of_empty_rows off of df_contenedor
    df_contenedor = df_contenedor.drop(list_of_empty_rows)

    # year -= 1


    # break
    # print(df)
    # Guardar en CSV
    # df.to_csv('csvs/csv1.csv', mode='a', header=True, index=False)
# remove last 2 rows
df_contenedor = df_contenedor.iloc[:-2]
df_contenedor['APORTE TOTAL(mm)'] = df_contenedor['APORTE TOTAL(mm)'].str.replace('.', '')
# Out:
# /tmp/ipykernel_21366/3783675290.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ANHO'] = year
# /tmp/ipykernel_21366/3783675290.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ANHO'] = year
# /tmp/ipykernel_21366/3783675290.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ANHO'] = year
# /tmp/ipykernel_21366/3783675290.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ANHO'] = year
# /tmp/ipykernel_21366/3783675290.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ANHO'] = year
# /tmp/ipykernel_21366/3783675290.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ANHO'] = year
# /tmp/ipykernel_21366/3783675290.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ANHO'] = year
# /tmp/ipykernel_21366/3783675290.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ANHO'] = year
# /tmp/ipykernel_21366/3783675290.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ANHO'] = year
# /tmp/ipykernel_21366/3783675290.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ANHO'] = year
# /tmp/ipykernel_21366/3783675290.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ANHO'] = year
# /tmp/ipykernel_21366/3783675290.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ANHO'] = year
# /tmp/ipykernel_21366/3783675290.py:44: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_contenedor['APORTE TOTAL(mm)'] = df_contenedor['APORTE TOTAL(mm)'].str.replace('.', '')

# %%
df_contenedor.tail(5)
# Out:
#      NRO                       NOMBRE O RAZON SOCIAL APORTE TOTAL(mm)  ANHO
# 495  496  DATA SYSTEMS SA EMISORA DE CAPITAL ABIERTO             2669  2020
# 496  497                                PROQUITEC SA             2662  2020
# 497  498                               GAS METAL SRL             2657  2020
# 498  499                          NUEVA AMERICANA SA             2649  2020
# 499  500                     RIVER SERVICES S. R. L.             2643  2020

# %%
df_contenedor.tail(5)
# Out:
#      NRO                       NOMBRE O RAZON SOCIAL APORTE TOTAL(mm)  ANHO
# 495  496  DATA SYSTEMS SA EMISORA DE CAPITAL ABIERTO             2669  2020
# 496  497                                PROQUITEC SA             2662  2020
# 497  498                               GAS METAL SRL             2657  2020
# 498  499                          NUEVA AMERICANA SA             2649  2020
# 499  500                     RIVER SERVICES S. R. L.             2643  2020

# %%
# concatenar al DF madre
df_madre = pd.concat([df_madre, df_contenedor], ignore_index=True)

# %% [markdown]
# # Graficar

# %%
df_madre.tail(5)
# Out:
#      NRO  RUC                       NOMBRE O RAZON SOCIAL APORTE TOTAL(mm)  \
# 995  496  NaN  DATA SYSTEMS SA EMISORA DE CAPITAL ABIERTO             2669
# 996  497  NaN                                PROQUITEC SA             2662
# 997  498  NaN                               GAS METAL SRL             2657
# 998  499  NaN                          NUEVA AMERICANA SA             2649
# 999  500  NaN                     RIVER SERVICES S. R. L.             2643
#
#      ANHO
# 995  2020
# 996  2020
# 997  2020
# 998  2020
# 999  2020

# %%
# filter only the rows with 'TABACALERA DEL ESTE SA' or 'BANCO ITAU PARAGUAY S.A' in NOMBRE O RAZON SOCIAL of df_madre
# df_madre_filtro = df_madre.loc[(df_madre['NOMBRE O RAZON SOCIAL'] == 'TABACALERA DEL ESTE SA') | (df_madre['NOMBRE O RAZON SOCIAL'] == 'BANCO ITAU PARAGUAY S.A')]
# comentar para tener todo el tataframe

# %%
# # order df by ANHO
# # df_madre_filtro = df_madre_filtro.sort_values(by=['ANHO'], ascending=True)
# df_madre = df_madre.sort_values(by=['ANHO'], ascending=True)

# df_madre.head(30)

# %% [markdown]
# # PDFs 3 al 9
# ### Años 2019 al 2013
# a partir de 2012, problema con el formato de los numeros

# %%
year = "2019"       # anho del primer PDF a leer
header = ['NRO'
         
          ,'RUC'
          ,'NOMBRE O RAZON SOCIAL'
          ,'APORTE TOTAL(mm)'
        ]

for i in range(3, 10):
    tables = camelot.read_pdf("pdfs/pdf" + str(i) + ".pdf", pages='1-end')

    # empty dataframe
    df_contenedor = pd.DataFrame(columns=header)

    for table in tables:
        df = table.df
        # remove the first row with loc
        df = df.loc[1:]
        df.columns = header
        # df['ANHO'] = year
        # create ANHO column with year value
        df.loc[:, 'ANHO'] = int(year)

        # concatenate the dataframe into a container dataframe
        df_contenedor = pd.concat([df_contenedor, df], ignore_index=True)
     
    
    # replace '.' with '' and parse APORTE TOTAL(mm) as int
    df_contenedor['APORTE TOTAL(mm)'] = df_contenedor['APORTE TOTAL(mm)'].str.replace('.', '')
    # df_contenedor['APORTE TOTAL(mm)'] = df_contenedor['APORTE TOTAL(mm)'].astype(int)
    # filter only the rows with 'TABACALERA DEL ESTE SA' or 'BANCO ITAU PARAGUAY S.A' in NOMBRE O RAZON SOCIAL of df_madre
    # df_contenedor = df_contenedor.loc[(df_contenedor['NOMBRE O RAZON SOCIAL'] == 'TABACALERA DEL ESTE SA') | (df_contenedor['NOMBRE O RAZON SOCIAL'] == 'BANCO ITAU PARAGUAY S.A') | (df_contenedor['NOMBRE O RAZON SOCIAL'] == 'PARAGUAY REFRESCOS SA')]
    # parse ANHO as int
    # df_contenedor['ANHO'] = df_contenedor['ANHO'].astype(int)
    # Concat to df_madre and sort by ANHO column


    # remove rows with empty string based on NRO column with loc
    df = df.loc[df['NRO'] != '']
    # get empty rows
    list_of_empty_rows = get_empty_rows(df)
    # remove rows of list_of_empty_rows off of df_contenedor
    df_contenedor = df_contenedor.drop(list_of_empty_rows)

    df_madre = pd.concat([df_madre, df_contenedor], ignore_index=True)

    print(f'''
    Procesando ... \n
    Archivo: pdfs/pdf{i}.pdf\n
    Anho: {year}
    ''')
    

    year = str(int(year) - 1)

# %%
df_madre.head(5)
# Out:
#   NRO       RUC                           NOMBRE O RAZON SOCIAL  \
# 0   1  80009735  ADMINISTRACION NACIONAL DE ELECTRICIDAD - ANDE
# 1   2  80008790                          TABACALERA DEL ESTE SA
# 2   3  80002201                         BANCO ITAU PARAGUAY S.A
# 3   4  80003400                           PARAGUAY REFRESCOS SA
# 4   5  80086846                                   CERVEPAR S.A.
#
#   APORTE TOTAL(mm)  ANHO
# 0           336481  2021
# 1           198331  2021
# 2           174807  2021
# 3           147677  2021
# 4           146989  2021

# %%
df_madre.tail(5)
# Out:
#       NRO       RUC                  NOMBRE O RAZON SOCIAL APORTE TOTAL(mm)  \
# 4495  496  80014443  RAFAELI SRL IMPORTADORA Y EXPORTADORA             1814
# 4496  497  80024926                          QUEEN ANNE SA             1812
# 4497  498  80002449               SUPERMERCADO GUARANI SRL             1809
# 4498  499  80019208                              DEZETA SA             1806
# 4499  500  80012667                       LA SANTANIANA SA             1806
#
#         ANHO
# 4495  2013.0
# 4496  2013.0
# 4497  2013.0
# 4498  2013.0
# 4499  2013.0

# %%
# shorten the column 'NOMBRE O RAZON SOCIAL' for better visualization
df_madre['NOMBRE O RAZON SOCIAL'] = df_madre['NOMBRE O RAZON SOCIAL'].str[:20]

# %%
df_madre['APORTE TOTAL(mm)'] = df_madre['APORTE TOTAL(mm)'].astype(int)

# %%
fig = px.line(df_madre, x="ANHO", y="APORTE TOTAL(mm)", color='NOMBRE O RAZON SOCIAL')
fig.show()
# Out:
# <div>                            <div id="d020e658-4719-4228-9294-6a2e2c7c7c88" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d020e658-4719-4228-9294-6a2e2c7c7c88")) {                    Plotly.newPlot(                        "d020e658-4719-4228-9294-6a2e2c7c7c88",                        [{"hovertemplate":"NOMBRE O RAZON SOCIAL=ADMINISTRACION NACIO<br>ANHO=%{x}<br>APORTE TOTAL(mm)=%{y}<extra></extra>","legendgroup":"ADMINISTRACION NACIO","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"ADMINISTRACION NACIO","showlegend":true,"x":["2021","2021","2020","2020",2019.0,2019.0,2018.0,2018.0,2017.0,2017.0,2016.0,2016.0,2015.0,2015.0,2014.0,2014.0,2013.0,2013.0],"xaxis":"x","y":[336481,12617,407807,10361,648882,8399,415224,8359,236712,7599,453088,6581,215840,6103,229278,6610,143315,6537],"yaxis":"y","type":"scattergl"},{"hovertemplate":"NOMBRE O RAZON SOCIAL=TABACALERA DEL ESTE <br>ANHO=%{x}<br>APORTE TOTAL(mm)=%{y}<extra></extra>","legendgroup":"TABACALERA DEL ESTE ","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"TABACALERA DEL ESTE ","showlegend":true,"x":["2021","2020",2019.0,2018.0,2017.0,2016.0,2015.0,2014.0,2013.0],"xaxis":"x","y":[198331,242106,344418,352094,332531,308345,249743,225700,204062],"yaxis":"y","type":"scattergl"},{"hovertemplate":"NOMBRE O RAZON SOCIAL=BANCO ITAU PARAGUAY <br>ANHO=%{x}<br>APORTE TOTAL(mm)=%{y}<extra></extra>","legendgroup":"BANCO ITAU PARAGUAY ","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"BANCO ITAU PARAGUAY ","showlegend":true,"x":["2021","2020",2019.0,2018.0,2017.0,2016.0,2015.0,2014.0,2013.0],"xaxis":"x","y":[174807,201577,229003,199828,201440,244862,211687,127110,106383],"yaxis":"y","type":"scattergl"},{"hovertemplate":"NOMBRE O RAZON SOCIAL=PARAGUAY REFRESCOS S<br>ANHO=%{x}<br>APORTE TOTAL(mm)=%{y}<extra></extra>","legendgroup":"PARAGUAY REFRESCOS S","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"PARAGUAY REFRESCOS S","showlegend":true,"x":["2021","2020",2019.0,2018.0,2017.0,2016.0,2015.0,2014.0,2013.0],"xaxis":"x","y":[147677,134907,153558,130820,121813,108015,103848,106160,78491],"yaxis":"y","type":"scattergl"},{"hovertemplate":"NOMBRE O RAZON SOCIAL=CERVEPAR S.A.<br>ANHO=%{x}<br>APORTE TOTAL(mm)=%{y}<extra></extra>","legendgroup":"CERVEPAR S.A.","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"CERVEPAR S.A.","showlegend":true,"x":["2021","2020",2019.0,2018.0,2017.0,2016.0,2015.0],"xaxis":"x","y":[146989,154792,228532,226852,197248,222539,72985],"yaxis":"y","type":"scattergl"},{"hovertemplate":"NOMBRE O RAZON SOCIAL=BANCO CONTINENTAL SA<br>ANHO=%{x}<br>APORTE TOTAL(mm)=%{y}<extra></extra>","legendgroup":"BANCO CONTINENTAL SA","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"BANCO CONTINENTAL SA","showlegend":true,"x":["2021","2020",2019.0,2018.0,2017.0,2016.0,2015.0,2014.0,2013.0],"xaxis":"x","y":[142276,116553,152645,164079,145407,185815,212818,109687,75595],"yaxis":"y","type":"scattergl"},{"hovertemplate":"NOMBRE O RAZON SOCIAL=BANCO NACIONAL DE FO<br>ANHO=%{x}<br>APORTE TOTAL(mm)=%{y}<extra></extra>","legendgroup":"BANCO NACIONAL DE FO","line":{"color":"#FF6692","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"BANCO NACIONAL DE FO","showlegend":true,"x":["2021","2020",2019.0,2018.0,2017.0,2016.0,2015.0,2014.0,2013.0],"xaxis":"x","y":[139376,157473,107778,63800,48145,53786,68980,42677,24823],"yaxis":"y","type":"scattergl"},{"hovertemplate":"NOMBRE O RAZON SOCIAL=VISION BANCO S.A.E.C<br>ANHO=%{x}<br>APORTE TOTAL(mm)=%{y}<extra></extra>","legendgroup":"VISION BANC ...

# %%
# reset index
df_madre = df_madre.reset_index(drop=True)
df_madre.describe()
# Out:
#          NRO       RUC NOMBRE O RAZON SOCIAL APORTE TOTAL(mm)  ANHO
# count   4500      4000                  4500             4500  4500
# unique   500      1078                  1146             3579     9
# top        1  80009735  CONTRIBUYENTE PERSON             3364  2021
# freq       9         8                    28                5   500

# %% [markdown]
# Conteo de lineas coincide con los datos descargados

# %%
df_madre.head(5)
# Out:
#   NRO       RUC NOMBRE O RAZON SOCIAL APORTE TOTAL(mm)  ANHO
# 0   1  80009735  ADMINISTRACION NACIO           336481  2021
# 1   2  80008790  TABACALERA DEL ESTE            198331  2021
# 2   3  80002201  BANCO ITAU PARAGUAY            174807  2021
# 3   4  80003400  PARAGUAY REFRESCOS S           147677  2021
# 4   5  80086846         CERVEPAR S.A.           146989  2021

# %%
df_madre.tail(5)
# Out:
#       NRO       RUC NOMBRE O RAZON SOCIAL APORTE TOTAL(mm)    ANHO
# 4495  496  80014443  RAFAELI SRL IMPORTAD             1814  2013.0
# 4496  497  80024926         QUEEN ANNE SA             1812  2013.0
# 4497  498  80002449  SUPERMERCADO GUARANI             1809  2013.0
# 4498  499  80019208             DEZETA SA             1806  2013.0
# 4499  500  80012667      LA SANTANIANA SA             1806  2013.0

# %%
# drop NRO column
df_madre = df_madre.drop(columns=['NRO'])
# export data to csv    
df_madre.to_csv('results/top_contribuyentes.csv', index=True)
